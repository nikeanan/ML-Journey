# %% [markdown]
# # Multiple Variable Linear Regression & Feature Visualization
# This notebook demonstrates feature visualization and linear regression with multiple features using NumPy and Matplotlib.

# %%
import numpy as np
import matplotlib.pyplot as plt
from lab_utils_multi import load_house_data, run_gradient_descent
from lab_utils_multi import norm_plot, plt_equal_scale, plot_cost_i_w
from lab_utils_common import dlc

np.set_printoptions(precision=2)
plt.style.use('./deeplearning.mplstyle')

# %%
# Load the dataset
def load_data():
    X_train, y_train = load_house_data()
    X_features = ['size(sqft)', 'bedrooms', 'floors', 'age']
    return X_train, y_train, X_features

# Load and assign dataset variables
X_train, y_train, X_features = load_data()

# %% [markdown]
# ### Dataset Overview & Notation
# - **$X$**: Training feature matrix ($m \times n$)
# - **$y$**: Target housing prices ($1000s$ of dollars)
# - **Features**: `size(sqft)`, `bedrooms`, `floors`, `age`

# %%
# Visualize each feature against housing prices
fig, ax = plt.subplots(1, 4, figsize=(14, 3.5), sharey=True)
for i in range(len(ax)):
    ax[i].scatter(X_train[:, i], y_train, color='crimson', alpha=0.7)
    ax[i].set_xlabel(X_features[i])
ax[0].set_ylabel("Price ($1000's)")
plt.suptitle("Housing Price vs Individual Features", fontsize=12)
plt.tight_layout()
plt.show()
